# %%
import json
import urllib

def elevation(lat, lng):
    apikey = "AIzaSyDjTjrZdOAQ2hZ4fTo-jyqO5wXs1FqptBY"
    url = "https://maps.googleapis.com/maps/api/elevation/json"
    request = urllib.request.urlopen(url+"?locations="+str(lat)+","+str(lng)+"&key="+apikey)
    results = json.load(request).get('results')
    if 0 < len(results):
        elevation = results[0].get('elevation')
        return [lat, lng, elevation]

def elevation_path(lat1, lng1, lng2, smpls):
    apikey = "AIzaSyDjTjrZdOAQ2hZ4fTo-jyqO5wXs1FqptBY"
    url = "https://maps.googleapis.com/maps/api/elevation/json"
    request = urllib.request.urlopen(url+"?path="+str(lat1)+","+str(lng1)+"|"+str(lat1)+","+str(lng2)+"&samples="+str(smpls)+"&key="+apikey)
    results = json.load(request).get('results')
    elevation_path = []
    for i in range(0, smpls):
        if 0 < len(results):
            elevation_path.append([lat1, lng1 + (i * ((lng2 - lng1) / smpls)), results[i].get('elevation')])
    return elevation_path

def elevation_matrix(lat1, lng1, lat2, lng2, smpls):
    int_dist = (lng2 - lng1) / smpls
    if lng2 < lng1:
        int_dist = -int_dist
    smpls_2 = (lat2 - lat1) / int_dist
    elevation_matrix = []
    for i in range(round(smpls_2)):
        elevation_matrix.append(elevation_path(lat1 + (i * int_dist), lng1, lng2, smpls))
    return elevation_matrix

# %%
elevation_matrix(44.295748, -78.3681295, 44.297859, -78.3584015, 20)
# Out:
# [[[44.295748, -78.3681295, 268.0725402832031],
#   [44.295748, -78.3676431, 266.204345703125],
#   [44.295748, -78.3671567, 264.9606323242188],
#   [44.295748, -78.3666703, 264.9712829589844],
#   [44.295748, -78.3661839, 264.6286315917969],
#   [44.295748, -78.3656975, 264.5872192382812],
#   [44.295748, -78.3652111, 264.9348449707031],
#   [44.295748, -78.3647247, 264.2455139160156],
#   [44.295748, -78.3642383, 262.209716796875],
#   [44.295748, -78.3637519, 260.5710754394531],
#   [44.295748, -78.3632655, 259.6830749511719],
#   [44.295748, -78.3627791, 258.3114318847656],
#   [44.295748, -78.3622927, 259.1671142578125],
#   [44.295748, -78.3618063, 257.1455078125],
#   [44.295748, -78.3613199, 257.17431640625],
#   [44.295748, -78.3608335, 254.2509765625],
#   [44.295748, -78.3603471, 251.6543426513672],
#   [44.295748, -78.3598607, 248.9888763427734],
#   [44.295748, -78.3593743, 246.7219848632812],
#   [44.295748, -78.3588879, 242.0289916992188]],
#  [[44.2962344, -78.3681295, 265.5091247558594],
#   [44.2962344, -78.3676431, 267.150634765625],
#   [44.2962344, -78.3671567, 266.5451049804688],
#   [44.2962344, -78.3666703, 266.45556640625],
#   [44.2962344, -78.3661839, 266.4343566894531],
#   [44.2962344, -78.3656975, 265.1102294921875],
#   [44.2962344, -78.3652111, 264.4314575195312],
